# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
dados = pd.read_csv(r'heart_failure.csv')

# %%
print('Colunas',dados.shape[1])
print('Linhas',dados.shape[0])
print('Dados Unicos \n',dados.nunique())
# Out:
# Colunas 13
# Linhas 299
# Dados Unicos
#  age                          47
# anaemia                       2
# creatinine_phosphokinase    208
# diabetes                      2
# ejection_fraction            17
# high_blood_pressure           2
# platelets                   176
# serum_creatinine             40
# serum_sodium                 27
# sex                           2
# smoking                       2
# time                        148
# DEATH_EVENT                   2
# dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
# age                         299 non-null float64
# anaemia                     299 non-null int64
# creatinine_phosphokinase    299 non-null int64
# diabetes                    299 non-null int64
# ejection_fraction           299 non-null int64
# high_blood_pressure         299 non-null int64
# platelets                   299 non-null float64
# serum_creatinine            299 non-null float64
# serum_sodium                299 non-null int64
# sex                         299 non-null int64
# smoking                     299 non-null int64
# time                        299 non-null int64
# DEATH_EVENT                 299 non-null int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
dados.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
sns.set_style('whitegrid')
plt.figure(figsize = (10,7))

sns.countplot('DEATH_EVENT',data = dados,palette = 'Set3')
plt.xlabel('Morte Confirmada',size = 13)
# Out:
# Text(0.5, 0, 'Morte Confirmada')

# %%
print('Porcentagem de Casos de Cura',round(dados['DEATH_EVENT'].value_counts()[0] / len(dados['DEATH_EVENT']),2) * 100,'%' )
print('Porcentagem de Casos de Obito',round(dados['DEATH_EVENT'].value_counts()[1] / len(dados['DEATH_EVENT']),2) * 100,'%' )
# Out:
# Porcentagem de Casos de Cura 68.0 %
# Porcentagem de Casos de Obito 32.0 %

# %%
dados['age'] = dados['age'].astype(int)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize = (10,7))

obito = dados.loc[dados['DEATH_EVENT'] == 1,'age']
cura = dados.loc[dados['DEATH_EVENT'] == 0,'age']

sns.distplot(obito, ax = ax1, color = 'r')
ax1.set_title('Mortes por Idade | Obito')
ax1.set_xlabel('Idade')

sns.distplot(cura, ax = ax2, color = 'g')
ax2.set_title('Mortes por Idade | Curado')
ax2.set_xlabel('Idade')
# Out:
# Text(0.5, 0, 'Idade')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize = (10,7))

obito = dados.loc[dados['DEATH_EVENT'] == 1,'platelets']
cura = dados.loc[dados['DEATH_EVENT'] == 0,'platelets']

sns.distplot(obito, ax = ax1, color = 'r')
ax1.set_title('Nª Plaquetas | Obito')
ax1.set_xlabel('Plaquetas')

sns.distplot(cura, ax = ax2, color = 'g')
ax2.set_title('Nª Plaquetas | Curado')
ax2.set_xlabel('Plaquetas')
# Out:
# Text(0.5, 0, 'Plaquetas')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize = (10,7))

obito = dados.loc[dados['DEATH_EVENT'] == 1,'serum_creatinine']
cura = dados.loc[dados['DEATH_EVENT'] == 0,'serum_creatinine']

sns.distplot(obito, ax = ax1, color = 'r')
ax1.set_title('creatinina sérica no corpo | Obito')
ax1.set_xlabel('Numero')

sns.distplot(cura, ax = ax2, color = 'g')
ax2.set_title('creatinina sérica no corpo | Curado')
ax2.set_xlabel('Numero')
# Out:
# Text(0.5, 0, 'Numero')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize = (10,7))

obito = dados.loc[dados['DEATH_EVENT'] == 1,'time']
cura = dados.loc[dados['DEATH_EVENT'] == 0,'time']

sns.distplot(obito, ax = ax1, color = 'r')
ax1.set_title('Tempo | Obito')
ax1.set_xlabel('Dias')

sns.distplot(cura, ax = ax2, color = 'g')
ax2.set_title('Tempo | Curado')
ax2.set_xlabel('Dias')
# Out:
# Text(0.5, 0, 'Dias')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize = (10,7))

obito = dados.loc[dados['DEATH_EVENT'] == 1,'smoking']
cura = dados.loc[dados['DEATH_EVENT'] == 0,'smoking']

sns.countplot(obito, ax = ax1, palette = 'Set1')
ax1.set_title('Fumante | Obito')
ax1.set_xlabel('Nao | Sim')

sns.countplot(cura, ax = ax2, palette = 'Set1')
ax2.set_title('Fumante | Curado')
ax2.set_xlabel('Nao | Sim')
# Out:
# Text(0.5, 0, 'Nao | Sim')

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize = (10,7))

obito = dados.loc[dados['DEATH_EVENT'] == 1,'anaemia']
cura = dados.loc[dados['DEATH_EVENT'] == 0,'anaemia']

sns.countplot(obito, ax = ax1, palette = 'Set1')
ax1.set_title('Anemia | Obito')
ax1.set_xlabel('Nao | Sim')

sns.countplot(cura, ax = ax2, palette = 'Set1')
ax2.set_title('Anemia | Curado')
ax2.set_xlabel('Nao | Sim')
# Out:
# Text(0.5, 0, 'Nao | Sim')

# %%
from sklearn.feature_selection import SelectKBest, chi2

sel = SelectKBest(chi2, k = 7)

x = dados.drop('DEATH_EVENT',axis = 1)
y = dados['DEATH_EVENT']

sel.fit_transform(x,y)
print(sel.scores_)
# Out:
# [4.45720960e+01 7.46593411e-01 1.89731484e+03 6.56814450e-04
#  7.90725412e+01 1.22153853e+00 2.61357720e+04 1.98141177e+01
#  1.61817451e+00 1.95626598e-03 3.23468288e-02 3.82689266e+03]

# %%
dados.head(0)
# Out:
# Empty DataFrame
# Columns: [age, anaemia, creatinine_phosphokinase, diabetes, ejection_fraction, high_blood_pressure, platelets, serum_creatinine, serum_sodium, sex, smoking, time, DEATH_EVENT]
# Index: []

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score
from sklearn.linear_model import LogisticRegression


x = dados[['anaemia','diabetes','ejection_fraction','smoking','time']]
y = dados[['DEATH_EVENT']]

x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 101,test_size = 0.2)

ln = LogisticRegression()
ln.fit(x_train,y_train)

print('Precisão no Treino')
ln.score(x_train,y_train) * 100
# Out:
# Precisão no Treino
# 82.84518828451883

# %%
y_pred = ln.predict(x_test)


print(accuracy_score(y_pred,y_test)* 100)
# Out:
# 88.33333333333333

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92        45
#            1       0.75      0.80      0.77        15
#
#    micro avg       0.88      0.88      0.88        60
#    macro avg       0.84      0.86      0.85        60
# weighted avg       0.89      0.88      0.88        60
